# %% [markdown]
# # Exploratory Data Analysis for Rail Road Crossing Accident
# ---
# *Data Source [Kaggle](https://www.kaggle.com/code/yogidsba/rail-road-crossing-accident-in-progress)
#
# <img style="width:100%" align="center" src="https://upload.wikimedia.org/wikipedia/commons/0/07/Trout_Lake%2C_Michigan_Railroad_crossing.JPG" width="600" align="center">
#
# *Image from [Wikimedia](https://upload.wikimedia.org/wikipedia/commons/0/07/Trout_Lake%2C_Michigan_Railroad_crossing.JPG)
#
# #Project Objective:
# Our goal is to predict the probability of the occurrence of an accident at railroad crossings in the US. We will benchmark machine learning models using Python on  challenging large-scale dataset to increase the efficacy of detecting accidents occurring at highway railroad crossings to make highway travel safer in the US.
#
#
# ## Introduction:
# In the United States, there are currently approximately 200,000 railroad grade crossings. Many commuters drive across railway crossings on a daily basis, never thinking about the dangers they may be exposing themselves to. While a train collision with a vehicle may appear implausible at first, such collisions are rather common in the United States.
#
# Statistics on railroad accidents and motor vehicle accidents:
#
#
# 1. A railroad grade crossing accident is 40 times more likely to kill motor
# vehicle drivers and passengers than a motor vehicle on motor vehicle accident.
#
# 2. Vehicles were involved in 2,025 collisions at railroad grade crossings in 2016.
#
# 3. In 2016, 265 persons were killed in railroad grade crossing accidents.
#
# 4. In 2016, 798 persons were injured in railroad grade crossing accidents.
#
# 5. In the United States, a train-on-car collision occurs every two/three hours on average.
#
# ## Dataset:
#
# The data was downloaded from Kaggle Data Set "Rail Road Crossing Accident": https://www.kaggle.com/code/yogidsba/rail-road-crossing-accident-in-progress
#
# Below is the dataset of railroad crossing accidents. This dataset has 141 columns and 239487 rows
#
# * Railroad Code: Code of the railroad
# * Railroad Name: Name of the railroad
# * Report Year: Year report published
# * Incident Number: Unique incident number
# * Incident Year: Year of the incident
# * Incident Month: Month of the incident
# * Other Railroad Code: Code of the other railroad involved
# * Other Railroad Name: Name of the other railroad involved
# * Other Incident Number: Unique incident number for the other railroad involved
# * Other Incident Year: Year of the incident
# * Other Incident Month: Month of the incident
# * Maintenance Incident Railroad Code: Code of the maintenance railroad
# * Maintenance Railroad Name :Name of the maintenance railroad
# Maintainance Incident Number :Unique incident number for the maintenance railroad
# * Maintenance Incident Year :Year of the incident
# * Maintenance Incident Month: Month of the incident
# * Grade Crossing ID Unique: grade crossing identification
# * Date :Incident date
# * Time :Incident time
# * Month :Incident month
# * Day :Incident day
# * Hour :Incident hour
# * Minute: Incident minute
# * AM/PM :AM or PM
# * Nearest Station: Nearest railroad station
# * Division: Division
# * Subdivision: Subdivision
# * County Code: FIPS county code
# * County Name: Name of County
# * State Code: FIPS state code
# * State Name: Name of state
# * City Name: Name of city if in a city
# * Highway Name: Name or number of highway
# * Public/Private Code: Highway public or private code
# * Public/Private: Highway public or private
# * Highway User Code: Type of highway user code
# * Highway User :Type of highway user
# * Estimated Vehicle Speed: Estimated vehicle speed at impact (mph)
# * Vehicle Direction Code: Direction of vehicle code
# * Vehicle Direction: Direction of vehicle
# * Highway User Position Code: Highway user position code in relation to crossing
# * Highway User Position :Highway user position in relation to crossing
# * Equipment Involved Code: Rail equipment involved code
# * Equipment Involved: Rail equipment involved
# * Railroad Car Unit Position: Position of impact car unit in train
# * Equipment Struck Code :Rail equipment struck highway user or struck by highway user code
# * Equipment Struck Rail :equipment struck highway user or struck by highway user
# * Hazmat Involvement Code: Highway user or rail equipment transporting highway materials code
# * Hazmat Involvement :Highway user or rail equipment transporting hazardous materials
# * Hazmat Released by Code: Hazardous materials released by highway user or rail equipment code
# * Hazmat Released by :Hazardous materials released by highway user or rail equipment
# * Hazmat Released Name :Name of hazardous materials released
# * Hazmat Released Quantity: Quantity of hazardous materials released
# * Hazmat Released Measure: Unit measure of hazardous materials released quantity
# * Temperature: Temperature at incident :(degrees Farenheit)
# * Visibility Code: Visibility during: incident code
# * Visibility :Visibility during :incident
# * Weather Condition Code: Weather condition during incident code
# * Weather Condition :Weather condition during incident
# * Equipment Type Code: Type of equipment consist code
# * Equipment Type: Type of equipment consist
# * Track Type Code: Track type used by rail equipment involved code
# * Track Type: Track type used by rail equipment involved
# * Track Name: Track number or name
# * Track Class: FRA track class
# * Number of Locomotive Units: Number of locomotive units involved
# * Number of Cars: Number of railroad cars involved
# * Train Speed: Speed of train involved
# * Estimated/Recorded Speed: Train speed was estimated or recorded
# * Train Direction Code: Direction of train involved code
# * Train Direction :Direction of train involved
# * Crossing Warning Expanded Code 1: Type of crossing warning code (12 possible)
# * Crossing Warning Expanded Code 2: Type of crossing warning code (12 possible)
# * Crossing Warning Expanded Code 3: Type of crossing warning code (12 possible)
# * Crossing Warning Expanded Code 4: Type of crossing warning code (12 possible)
# * Crossing Warning Expanded Code 5: Type of crossing warning code (12 possible)
# * Crossing Warning Expanded Code 6: Type of crossing warning code (12 possible)
# * Crossing Warning Expanded Code 7: Type of crossing warning code (12 possible)
# * Crossing Warning Expanded Code 8: Type of crossing warning code (12 possible)
# * Crossing Warning Expanded Code 9: Type of crossing warning code (12 possible)
# * Crossing Warning Expanded Code 10: Type of crossing warning code (12 possible)
# * Crossing Warning Expanded Code 11 :Type of crossing warning code (12 possible)
# * Crossing Warning Expanded Code 12 :Type of crossing warning code (12 possible)
# * Crossing Warning Expanded 1 :Type of crossing warning (12 possible)
# * Crossing Warning Expanded 2 :Type of crossing warning (12 possible)
# * Crossing Warning Expanded 3 :Type of crossing warning (12 possible)
# * Crossing Warning Expanded 4 :Type of crossing warning (12 possible)
# * Crossing Warning Expanded 5 :Type of crossing warning (12 possible)
# * Crossing Warning Expanded 6 :Type of crossing warning (12 possible)
# * Crossing Warning Expanded 7 :Type of crossing warning (12 possible)
# * Crossing Warning Expanded 8 :Type of crossing warning (12 possible)
# * Crossing Warning Expanded 9 :Type of crossing warning (12 possible)
# * Crossing Warning Expanded 10 :Type of crossing warning (12 possible)
# * Crossing Warning Expanded 11 :Type of crossing warning (12 possible)
# * Crossing Warning Expanded 12 :Type of crossing warning (12 possible)
# * Signaled Crossing Warning Code: Status of warning devices at crossing during incident code
# * Signaled Crossing Warning :Status of warning devices at crossing during incident
# * Crossing Warning Explanation Code:
# * Crossing Warning Explanation:
# * Roadway Condition Code :Roadway condition at time of incident code
# * Roadway Condition :Roadway condition at time of incident
# * Crossing Warning Location Code: Location of crossing warning code
# * Crossing Warning Location: Location of crossing warning
# * Warning Connected To Signal: Warning was connected to highway signals
# * Crossing Illuminated :Crossing was illuminated by street lights or special lights
# * User Age :Highway user's age
# * User Gender: Highway user's gender
# * User Struck By Second Train: Highway user went behind or in front of train and was struck or was struck by a second train
# * Highway User Action Code: Highway user action contributing to incident code
# * Highway User Action :Highway user action contributing to incident
# * Driver Passed Vehicle :Driver passed standing highway vehicle
# * View Obstruction Code :View of track obscured bb code
# * View Obstruction :View of track obscured by
# * Driver Condition Code: Driver condition after incident code
# * Driver Condition :Driver condition after incident
# * Driver In Vehicle :Driver was in the vehicle
# * Crossing Users Killed For Reporting Railroad: Number of highway-rail crossing users killed
# * Crossing Users Injured For Reporting Railroad: Number of highway-rail crossing users injured
# * Vehicle Damage Cost :Highway vehicle property damage cost
# * Number Vehicle Occupants :Total number of vehicle occupants including driver
# * Employees Killed For Reporting Railroad: Number of railroad employees killed
# * Employees Injured For Reporting Railroad: Number of railroad employees injured
# * Number People On Train: Total number of people on train including passengers and train crew
# * Form 54 Filed :Was a rail equipment accident/incident report filed
# * Passengers Killed For Reporting Railroad: Number of passengers on train killed
# * Passengers Injured For Reporting Railroad: Number of passengers on train injured
# * Video Taken: Video of incident was taken
# * Video Used: Video of incident was used
# * Special Study 1:
# * Special Study 2:
# * Narrative :Narrative description of incident
# * Total Killed Form 57 :Number killed as reported on Form 57
# * Total Injured Form 57 :Number injured as reported on Form 57
# * Railroad Type: Railroad Type
# * Joint Code: Joint Code
# * Total Killed Form 55A :Number killed as reported on Form 55A
# * Total Injured Form 55A: Number injured as reported on Form 55A
# * District :District
# * Whistle Ban Code: Whistle ban in effect code
# * Whistle Ban :Whistle ban in effect
# * Report Key :Unique identifier for Form 57 report
#
# Our goal is to predict the probability of the occurrence of an accident at
# railroad crossings in the US using this dataset.For this, we will be using Python, Pandas, MatPlotLib and Seaborn library to plot and analyze the data. We will also use GNB model to predict accuracy of our model in predicting State with maximum nunber of railroad accidents.
#
# **Basic information**:
# * 239487 rows
# * There are 141 columns

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import plotly.express as px
import plotly.graph_objects as go
import warnings 
warnings.filterwarnings('ignore')

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#https://drive.google.com/file/d/10vC8flVchwAck0Ckk-CiM77b6NwhdNH0/view?usp=sharing
fileDownloaded = drive.CreateFile({'id':'10vC8flVchwAck0Ckk-CiM77b6NwhdNH0'})
fileDownloaded.GetContentFile('Highway-Rail_Grade_Crossing_Accident_Data.csv')
df1 = pd.read_csv('Highway-Rail_Grade_Crossing_Accident_Data.csv')
df1.head(3)
# Out:
#   Railroad Code                     Railroad Name  Report Year  \
# 0          BNSF              BNSF Railway Company         2009
# 1          BNSF              BNSF Railway Company         2009
# 2            NS  Norfolk Southern Railway Company         2020
#
#   Incident Number  Incident Year  Incident Month Other Railroad Code  \
# 0       CA0109200              9               1                 NaN
# 1       CA0109201              9               1                 NaN
# 2          139633             20              11                 NaN
#
#   Other Railroad Name Other Incident Number  Other Incident Year  ...  \
# 0                 NaN                   NaN                  NaN  ...
# 1                 NaN                   NaN                  NaN  ...
# 2                 NaN                   NaN                  NaN  ...
#
#    Total Killed Form 57 Total Injured Form 57 Railroad Type Joint Code  \
# 0                     0                     1            1L          1
# ...

# %%
#df1.corr()

# %% [markdown]
# # Data Visualization:

# %%
df1.info()
print ("Total Rows in dataset: " , df1.shape[0])  
print ("Total Columns in dataset: " , df1.shape[1])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239487 entries, 0 to 239486
# Columns: 141 entries, Railroad Code to Report Key
# dtypes: float64(50), int64(12), object(79)
# memory usage: 257.6+ MB
# Total Rows in dataset:  239487
# Total Columns in dataset:  141

# %% [markdown]
# ## Target Variable:
# We are trying to predict the pattern for Rail Road Crossing Accident in the United States. We want to get a sense of the states and railroads with maximum number of accidents and the most important factors responsible for such accidents.
# We have a very large dataset with multiple features and a set of target variables indicating the accidents, some indicating accidents as people killed and some as people injured.
#
# The sum of all the columns below against all other factors will help us predict the pattern properly:
# * Employees Killed For Reporting Railroad
# * Employees Injured For Reporting Railroad
# * Crossing Users Killed For Reporting Railroad
# * Crossing Users Injured For Reporting Railroad
# * Passengers Killed For Reporting Railroad
# * Passengers Injured For Reporting Railroad

# %% [markdown]
# ## Data cleaning and defining feature Columns for the dataset:

# %%
#Since we have a very big dataset thus we are creating a dataframe with most important columns responsible for the accidents 
df_rail_road_crossing_accident = df1[['Railroad Name',
                      'Report Year', 
                      'Time',
                      'Incident Month',
                      'Date', 
                      'Day', 
                      'County Name',
                      'State Name',
                      'City Name', 
                      'Highway Name', 
                      'Estimated Vehicle Speed',
                      'Highway User Position', 
                      'Equipment Involved',
                      'Equipment Struck', 
                      'Temperature', 
                       'Visibility', 
                       'Weather Condition',
                       'Track Type',
                        'Track Name', 
                       'Number of Locomotive Units',
                       'Train Speed', 
                      'Estimated/Recorded Speed',
                       'Roadway Condition',
                      'Crossing Illuminated',
                      'Signaled Crossing Warning',
                      'User Age', 
                      'User Gender', 
                      'User Struck By Second Train',
                      'Highway User Action',
                      'Driver Passed Vehicle', 
                       'View Obstruction',
                       'Driver Condition',
                      'Driver In Vehicle', 
                      'Number People On Train', 
                      'Other Incident Month','Highway User Position Code',
                      'Railroad Car Unit Position',
                      'Crossing Users Killed For Reporting Railroad',
                       'Passengers Killed For Reporting Railroad',
                       'Employees Killed For Reporting Railroad',
                       'Crossing Users Injured For Reporting Railroad',
                       'Passengers Injured For Reporting Railroad'
                        ,'Employees Injured For Reporting Railroad',
                        'Hour',
                        'Month',
                        'Total Killed Form 57', 
                        'Total Injured Form 57',
                        'Total Killed Form 55A',
                         'Total Injured Form 55A',
                      ]]
df_rail_road_crossing_accident.dropna()
df_rail_road_crossing_accident.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239487 entries, 0 to 239486
# Data columns (total 49 columns):
#  #   Column                                         Non-Null Count   Dtype
# ---  ------                                         --------------   -----
#  0   Railroad Name                                  239479 non-null  object
#  1   Report Year                                    239487 non-null  int64
#  2   Time                                           239487 non-null  object
#  3   Incident Month                                 239487 non-null  int64
#  4   Date                                           239477 non-null  object
#  5   Day                                            239487 non-null  int64
#  6   County Name                                    239209 non-null  object
#  7   State Name                                     239482 non-null  object
#  8   City Name                                      198193 non-null  object
# ...

# %%
df_rail_road_crossing_accident.isna().sum()
# Out:
# Railroad Name                                         8
# Report Year                                           0
# Time                                                  0
# Incident Month                                        0
# Date                                                 10
# Day                                                   0
# County Name                                         278
# State Name                                            5
# City Name                                         41294
# Highway Name                                       2471
# Estimated Vehicle Speed                           27286
# Highway User Position                               398
# Equipment Involved                                    0
# Equipment Struck                                      4
# Temperature                                           1
# Visibility                                           16
# Weather Condition                                   145
# ...

# %% [markdown]
# There are lots of missing values in many features.
# We will still try to visualize some data

# %%
df_rail_road_crossing_accident.describe().T
# Out:
#                                                   count         mean  \
# Report Year                                    239487.0  1989.534543
# Incident Month                                 239487.0     6.520567
# Day                                            239487.0    15.567684
# Estimated Vehicle Speed                        212201.0    11.522754
# Temperature                                    239486.0    56.310636
# Number of Locomotive Units                     239474.0     2.174574
# Train Speed                                    237133.0    24.337971
# User Age                                        53298.0    41.118241
# Number People On Train                          63459.0    16.429647
# Other Incident Month                             4554.0     6.409750
# Highway User Position Code                     239089.0     2.628385
# Railroad Car Unit Position                     238230.0     3.065991
# Crossing Users Killed For Reporting Railroad   237239.0     0.100005
# ...

# %% [markdown]
# ## Observations:
# 1. We have to work on this dataset with great precision as the number of accidents took place, which is spread over 6 columns( **'Crossing Users Killed For Reporting Railroad', 'Passengers Killed For Reporting Railroad', 'Employees Killed For Reporting Railroad', 'Crossing Users Injured For Reporting Railroad', 'Passengers Injured For Reporting Railroad', 'Employees Injured For Reporting Railroad'**), should be the sum and not the count of data variables.
#
# 2. We will analyse features like "Number of Locomotive Units","Number People On Train" etc. to understand what kind of incident it was
#
# 3. Also, we have to get rid of wrong data like: maximum temperature 870, to make dataset more accurate

# %% [markdown]
# ##Getting Insights into the data using Seaborn and Matplotlib Plots:
# Examining the year with the highest number of accidents and determining if the pattern changes over time

# %%
# dataset to store all the accidents  
df_accidents = df_rail_road_crossing_accident[['Crossing Users Killed For Reporting Railroad',
                       'Passengers Killed For Reporting Railroad',
                       'Employees Killed For Reporting Railroad',
                       'Crossing Users Injured For Reporting Railroad',
                       'Passengers Injured For Reporting Railroad'
                        ,'Employees Injured For Reporting Railroad']]
df_rail_road_crossing_accident['Accidents'] = df_accidents.sum(axis=1)
# Total number of accidents
df_rail_road_crossing_accident['Accidents_Sum'] = df_rail_road_crossing_accident['Accidents']

# %%
df_rail_road_crossing_accident.pivot_table(values='Accidents', index=None, columns="Report Year", aggfunc='sum').T
# Out:
#              Accidents
# Report Year
# 1975            4777.0
# 1976            5855.0
# 1977            5858.0
# 1978            5515.0
# 1979            5261.0
# 1980            4726.0
# 1981            4021.0
# 1982            3244.0
# 1983            3198.0
# 1984            3559.0
# 1985            3269.0
# 1986            3074.0
# 1987            3053.0
# 1988            3278.0
# 1989            3669.0
# 1990            3105.0
# 1991            2702.0
# 1992            2554.0
# 1993            2463.0
# 1994            2576.0
# 1995            2473.0
# 1996            2098.0
# 1997            1903.0
# 1998            1676.0
# 1999            1808.0
# 2000            1659.0
# 2001            1578.0
# 2002            1358.0
# 2003            1369.0
# 2004            1466.0
# 2005            1415.0
# 2006            1442.0
# 2007            1407.0
# 2008            1284.0
# 2009             992.0
# 2010            1151.0
# 2011            1322.0
# 2012            1255.0
# ...

# %%
df_yearwise_accidents = (df_rail_road_crossing_accident.groupby("Report Year")["Accidents"].sum()).to_frame(name = 'Total_Accidents').reset_index()
#print(df_yearwise_accidents)
sns.catplot(x="Report Year", y="Total_Accidents",
                kind="bar",
                data=df_yearwise_accidents, aspect=5)


# exporting to a csv file                                                             
df_yearwise_accidents.to_csv(r'/content/df_yearwise_accidents.csv', index=False)

# %% [markdown]
# It is evident from the above plot that 1977 has maximum number of accidents
# and the number of accidents reduced effectively with time.

# %% [markdown]
# ##State-wise distribution of accidents in the United States from year 1975 to 2001:

# %%
df_rail_road_crossing_accident.pivot_table(values='Accidents', index = None, columns='State Name', aggfunc='sum').T
# Out:
#                       Accidents
# State Name
# ALABAMA                  3567.0
# ALASKA                    126.0
# ARIZONA                   665.0
# ARKANSAS                 3097.0
# CALIFORNIA               5946.0
# COLORADO                 1228.0
# CONNECTICUT               238.0
# DELAWARE                  181.0
# DISTRICT OF COLUMBIA        7.0
# FLORIDA                  3885.0
# GEORGIA                  3709.0
# HAWAII                      0.0
# IDAHO                     874.0
# ILLINOIS                 8155.0
# INDIANA                  6133.0
# IOWA                     2458.0
# KANSAS                   2622.0
# KENTUCKY                 2075.0
# LOUISIANA                5659.0
# MAINE                     215.0
# MARYLAND                  499.0
# MASSACHUSETTS             413.0
# MICHIGAN                 4175.0
# MINNESOTA                2499.0
# MISSISSIPPI              3775.0
# MISSOURI                 2990.0
# MONTANA                   570.0
# NEBRASKA                 1777.0
# ...

# %% [markdown]
# Visualizing the above obtained data with a countplot:

# %%
import matplotlib.colors as mcolors
df_statewise_accidents = (df_rail_road_crossing_accident.groupby("State Name")["Accidents"].sum()).to_frame(name = 'Total_Accidents').reset_index()
#print(df_statewise_accidents)

# exporting to a csv file                                                             
df_statewise_accidents.to_csv(r'/content/df_statewise_accidents.csv', index=False)

# %%
# plotting graph:
clist = [(0, "red"), (0.125, "red"), (0.25, "orange"), (0.5, "green"), 
         (0.7, "green"), (0.75, "blue"), (1, "blue")]
rvb = mcolors.LinearSegmentedColormap.from_list("", clist)
total_killed = df_statewise_accidents['Total_Accidents']
labels = df_statewise_accidents['State Name']
N=50
x = np.arange(len(labels))  
width = 0.50  
plt.figure(figsize=(25,8))
rects = plt.bar(x - width/2, total_killed, width,color=rvb(x/N))
plt.xticks(rotation=70, ha='right')
plt.ylabel('Accidents')
plt.xlabel('States')
plt.title('Number of accidents state wise')
plt.xticks(x, labels)
plt.show()

# %% [markdown]
# ** *From the above obtained count and  plot it is clear that in the United States, Texas has maximum number of Rail Road accidents, followed by Illinois, Ohio and Indiana.***

# %% [markdown]
# ## Visualizing state-wise data from past 10 years to find:
# * the state with maximum accidents and plotting same on the US map
# * impact of weather conditions on accidents in these states

# %%
df_recent_accidents = df_rail_road_crossing_accident[(df_rail_road_crossing_accident['Report Year']>2010)]

df_recent_accidents.pivot_table(values='Accidents', index = None, columns='State Name', aggfunc='sum').T
# Out:
#                       Accidents
# State Name
# ALABAMA                   453.0
# ALASKA                      0.0
# ARIZONA                    90.0
# ARKANSAS                  255.0
# CALIFORNIA               1215.0
# COLORADO                  117.0
# CONNECTICUT                29.0
# DELAWARE                   22.0
# DISTRICT OF COLUMBIA        3.0
# FLORIDA                   572.0
# GEORGIA                   497.0
# IDAHO                      72.0
# ILLINOIS                  738.0
# INDIANA                   560.0
# IOWA                      200.0
# KANSAS                    205.0
# KENTUCKY                  248.0
# LOUISIANA                 556.0
# MAINE                      19.0
# MARYLAND                   77.0
# MASSACHUSETTS              59.0
# MICHIGAN                  285.0
# MINNESOTA                 247.0
# MISSISSIPPI               385.0
# MISSOURI                  279.0
# MONTANA                    65.0
# NEBRASKA                  175.0
# NEVADA                    116.0
# ...

# %%
code = {'Alabama': 'AL',
        'Alaska': 'AK',
        'Arizona': 'AZ',
        'Arkansas': 'AR',
        'California': 'CA',
        'Colorado': 'CO',
        'Connecticut': 'CT',
        'Delaware': 'DE',
        'District of Columbia': 'DC',
        'Florida': 'FL',
        'Georgia': 'GA',
        'Hawaii': 'HI',
        'Idaho': 'ID',
        'Illinois': 'IL',
        'Indiana': 'IN',
        'Iowa': 'IA',
        'Kansas': 'KS',
        'Kentucky': 'KY',
        'Louisiana': 'LA',
        'Maine': 'ME',
        'Maryland': 'MD',
        'Massachusetts': 'MA',
        'Michigan': 'MI',
        'Minnesota': 'MN',
        'Mississippi': 'MS',
        'Missouri': 'MO',
        'Montana': 'MT',
        'Nebraska': 'NE',
        'Nevada': 'NV',
        'New Hampshire': 'NH',
        'New Jersey': 'NJ',
        'New Mexico': 'NM',
        'New York': 'NY',
        'North Carolina': 'NC',
        'North Dakota': 'ND',
        'Ohio': 'OH',
        'Oklahoma': 'OK',
        'Oregon': 'OR',
        'Pennsylvania': 'PA',
        'Rhode Island': 'RI',
        'South Carolina': 'SC',
        'South Dakota': 'SD',
        'Tennessee': 'TN',
        'Texas': 'TX',
        'Utah': 'UT',
        'Vermont': 'VT',
        'Virginia': 'VA',
        'Washington': 'WA',
        'West Virginia': 'WV',
        'Wisconsin': 'WI',
        'Wyoming': 'WY'}

df_recent_accidents['State Name'] =df_recent_accidents['State Name'].str.capitalize()
df_recent_accidents['Code']=df_recent_accidents['State Name'].map(code)

# %%
df_recent_statewise_accidents = (df_recent_accidents.groupby("Code")["Accidents"].sum()).to_frame(name = 'Total_Accidents').reset_index()
#print(df_recent_statewise_accidents)

# exporting to a csv file                                                             
df_recent_statewise_accidents.to_csv(r'/content/df_recent_statewise_accidents.csv', index=False)

# %%
fig = go.Figure(data = go.Choropleth(
    locations = df_recent_statewise_accidents['Code'],
    locationmode = 'USA-states',
    colorscale = 'rainbow',
    text = df_recent_statewise_accidents['Code'],
    z = df_recent_statewise_accidents['Total_Accidents'],
    colorbar_title = "State Wise Accident Report"

))
       
fig.update_layout(
    title_text = 'State Wise Accident Report from 2010 to 2021 in United States',
    geo_scope = 'usa'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ** *From the above map it is clear that in last 10 years, Texas is still leading the board with maximum number of Rail Road accidents, but the number of accidents reduced in Illinois and Indiana. While the number of accidents in California has increased significantly and became equal to Texas in last ten years.***

# %% [markdown]
# Accidents in States during different weather conditions:

# %%
((pd.pivot_table(df_recent_accidents, values=["Accidents"], columns="State Name", index="Weather Condition", aggfunc="sum").T).dropna()).sort_values(by=['State Name'],ascending = False)
# Out:
# Weather Condition        Clear  Cloudy   Fog  Rain  Sleet  Snow
#           State Name
# Accidents Wisconsin      129.0    47.0   4.0  12.0    1.0  13.0
#           Washington      84.0    61.0   3.0  17.0    0.0   3.0
#           Virginia       107.0    32.0   0.0   8.0    0.0   3.0
#           Utah            67.0    22.0   1.0   3.0    0.0   3.0
#           Texas          865.0   292.0   8.0  48.0    1.0   1.0
#           South dakota    39.0     8.0   3.0   0.0    1.0   0.0
#           Pennsylvania   171.0    58.0  15.0  25.0    0.0  10.0
#           Oklahoma       181.0    47.0   2.0   8.0    1.0   1.0
#           Ohio           232.0    68.0   4.0  24.0    0.0  17.0
#           North dakota    98.0    26.0   1.0   0.0    0.0   3.0
#           New york       166.0    42.0   1.0  26.0    1.0   7.0
#           New jersey     125.0    36.0  11.0  23.0    0.0  11.0
#           Nebraska       131.0    33.0   4.0   4.0    0.0   3.0
# ...

# %%
df_recent_railroad_and_weather = (df_recent_accidents.groupby(["State Name","Weather Condition"])["Accidents"].sum()).to_frame(name = 'Total_Accidents').reset_index()
df_recent_railroad_and_weather.head(10)
# Out:
#   State Name Weather Condition  Total_Accidents
# 0    Alabama             Clear            352.0
# 1    Alabama            Cloudy             73.0
# 2    Alabama               Fog              0.0
# 3    Alabama              Rain             22.0
# 4    Alabama             Sleet              1.0
# 5    Alabama              Snow              5.0
# 6     Alaska             Clear              0.0
# 7     Alaska            Cloudy              0.0
# 8    Arizona             Clear             83.0
# 9    Arizona            Cloudy              6.0

# %% [markdown]
# *Although different states have different geographies, the maximum number of accidents in most of the states took place under Clear weather conditions.*

# %% [markdown]
# ##Checking the railway roads and state they belong to in the last 10 years with maximum number of accidents:

# %%
((pd.pivot_table(df_recent_accidents, values=["Accidents"], columns=["Railroad Name","Code"], index=None, aggfunc="sum").T).dropna()).sort_values(by=['Accidents'],ascending = False)
# Out:
#                                                        Accidents
# Railroad Name                                    Code
# Union Pacific Railroad Company                   TX        674.0
# Amtrak (National Railroad Passenger Corporation) CA        474.0
# BNSF Railway Company                             TX        243.0
# Norfolk Southern Railway Company                 GA        236.0
# CSX Transportation                               IN        233.0
# ...                                                          ...
# R. J. Corman Railroad Company/Cleveland Line     OH          0.0
# R. J. Corman Railroad Company/Memphis Line       KY          0.0
# Fulton County Railway                            GA          0.0
# R. J. Corman, Western Ohio Line                  OH          0.0
# Youngstown & Southeastern Railroad Company, Inc. OH          0.0
#
# [597 rows x 1 columns]

# %%
df_recent_railroad_accidents = (df_recent_accidents.groupby(["Railroad Name","Code"])["Accidents"].sum()).to_frame(name = 'Total_Accidents').reset_index()

# %% [markdown]
# ***Pivot table data analysis corroborates the fact that the railway roads in Texas have maximum number of accidents.***

# %% [markdown]
# ##Relation between Weather conditions and Accidents

# %%
# data from last 10 years
pd.pivot_table(df_recent_accidents, values="Accidents", index=None, columns="Weather Condition", aggfunc="sum").T
# Out:
#                    Accidents
# Weather Condition
# Clear                 8768.0
# Cloudy                2292.0
# Fog                    142.0
# Rain                   596.0
# Sleet                   20.0
# Snow                   208.0

# %%
# old data from 1975
pd.pivot_table(df_rail_road_crossing_accident, values="Accidents", index=None, columns="Weather Condition", aggfunc="sum").T
# Out:
#                    Accidents
# Weather Condition
# Clear                76984.0
# Cloudy               23347.0
# Fog                   2102.0
# Rain                  7710.0
# Sleet                  226.0
# Snow                  2442.0

# %%
df_weather_conditions = (df_recent_accidents.groupby("Weather Condition")["Accidents"].sum()).to_frame(name = 'Total_Accidents').reset_index()

# exporting to a csv file                                                             
df_weather_conditions.to_csv(r'/content/df_weather_conditions.csv', index=False)

print(df_weather_conditions)
y = np.array(df_weather_conditions['Total_Accidents'])
mylabels = ["Clear", "Cloudy", "Rain","Snow","Fog","Sleet"]
myexplode = [0.1, 0.05, 0.05, 0.05, 0.05, 0.05]
mycolor = ['lightskyblue','deepskyblue','blue','powderblue','cornflowerblue','indigo']

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True, radius= 2, colors=mycolor)
plt.legend(title = "Weather:")
plt.show()
# Out:
#   Weather Condition  Total_Accidents
# 0             Clear           8768.0
# 1            Cloudy           2292.0
# 2               Fog            142.0
# 3              Rain            596.0
# 4             Sleet             20.0
# 5              Snow            208.0

# %% [markdown]
# ***The pivot table and pie chart confirms that the maximum number of accidents take place in Clear weather, followed by Cloudy and Rainy weather conditions.
# This trend holds true from 1975-2021.
# ***

# %% [markdown]
# ## Getting insights into Number of accidents during Day vs Night using Pivot table

# %%
df_recent_accidents['Time']= pd.to_datetime(df_recent_accidents['Time']).dt.strftime('%H')
df_recent_accidents['Time'] = df_recent_accidents['Time'].astype('int64', copy=False)
df_rail_road_crossing_accident['Time']= df_recent_accidents['Time']

df_accident_time = df_recent_accidents[['Time',
                                      'Accidents',  
                                     'Crossing Users Killed For Reporting Railroad',
                                     'Crossing Users Injured For Reporting Railroad', 
                                     'Passengers Killed For Reporting Railroad',
                                     'Passengers Injured For Reporting Railroad',
                                     'Employees Injured For Reporting Railroad',
                                     'Employees Killed For Reporting Railroad',         
                                     ]]
df_accident_time.dropna()

#df_accident_time['Time']= pd.to_datetime(df_accident_time['Time']).dt.strftime('%H')
#df_accident_time['Time'] = df_accident_time['Time'].astype('int64', copy=False)

pd.pivot_table(df_accident_time, values="Accidents", index=None, columns="Time", aggfunc="sum").T
# Out:
#       Accidents
# Time
# 0         266.0
# 1         249.0
# 2         240.0
# 3         168.0
# 4         146.0
# 5         169.0
# 6         294.0
# 7         485.0
# 8         621.0
# 9         613.0
# 10        690.0
# 11        790.0
# 12        838.0
# 13        830.0
# 14        731.0
# 15        817.0
# 16        770.0
# 17        732.0
# 18        669.0
# 19        566.0
# 20        393.0
# 21        381.0
# 22        307.0
# 23        268.0

# %%
df_recent_railroad_accidents = (df_accident_time.groupby("Time")["Accidents"].sum()).to_frame(name = 'Total_Accidents').reset_index()
#print(df_recent_railroad_accidents)

# exporting to a csv file                                                             
df_recent_railroad_accidents.to_csv(r'/content/df_recent_railroad_accidents_time.csv', index=False)

# %%
df_recent_railroad_accidents[(df_recent_railroad_accidents['Time']>=7) & (df_recent_railroad_accidents['Time']<=19)].shape[0] / df_recent_railroad_accidents.shape[0]
# Out:
# 0.5416666666666666

# %%
df_recent_railroad_accidents[(df_recent_railroad_accidents['Time']>19) | (df_recent_railroad_accidents['Time']<7)].shape[0] / df_recent_railroad_accidents.shape[0]
# Out:
# 0.4583333333333333

# %% [markdown]
# Accidents in Day(7 am to 7 pm inclusive) vs Night(greater than 7 pm and less than 7 am):
# * Day: 0.5416
#
# * Night: 0.4583

# %%
ax = sns.catplot(y="Total_Accidents", x="Time", kind="bar", data=df_recent_railroad_accidents, height=10, aspect=2.5)

# %% [markdown]
# ***It is confirmed with our above analysis that maximum number of accidents took place in day over night. ***

# %% [markdown]
# Accidents of crossing users, train passengers and employees in day and night are plotted below:

# %%
df_accident_time['total_crossing_users'] = sum(df_accident_time["Crossing Users Killed For Reporting Railroad"],df_accident_time["Crossing Users Injured For Reporting Railroad"])
df_recent_users_killed = (df_accident_time.groupby(['Time'])["total_crossing_users"].sum()).to_frame(name = 'Total_Accidents').reset_index()

labels = df_recent_users_killed['Time']

total_user_acc = df_recent_users_killed['Total_Accidents']

x = np.arange(len(labels)) 
width = 0.35  
plt.figure(figsize=(12,8))
plt.bar(x - width/2, total_user_acc, width)
plt.ylabel('No. of accidents')
plt.xlabel('Time')
plt.title('Number of crossing users accidents in day vs night(Time: 0 to 23)')
plt.xticks(x, labels)
plt.show()

# %%
# plot for employees accidents (killed and injured)
df_accident_time['total_emp']= sum(df_accident_time["Employees Killed For Reporting Railroad"],df_accident_time["Employees Injured For Reporting Railroad"])
df_recent_emp_killed = (df_accident_time.groupby(['Time'])["total_emp"].sum()).to_frame(name = 'Total_Accidents').reset_index()

labels = df_recent_emp_killed['Time']

total_acc = df_recent_emp_killed['Total_Accidents']

x = np.arange(len(labels)) 
width = 0.35  
plt.figure(figsize=(12,8))
plt.bar(x - width/2, total_acc, width)
plt.ylabel('No. of accidents')
plt.xlabel('Time')
plt.title('Number of employee accidents in day vs night(Time: 0 to 23)')
plt.xticks(x, labels)
plt.show()

# %%
# plot for passengers accidents (killed and injured)
df_accident_time['total_pass']= sum(df_accident_time["Passengers Killed For Reporting Railroad"],df_accident_time["Passengers Injured For Reporting Railroad"])
df_recent_pass_killed = (df_accident_time.groupby(['Time'])["total_pass"].sum()).to_frame(name = 'Total_Accidents').reset_index()

labels = df_recent_pass_killed['Time']
total_accident = df_recent_pass_killed['Total_Accidents']

x = np.arange(len(labels)) 
width = 0.35  
plt.figure(figsize=(12,8))
plt.bar(x - width/2, total_accident, width)
plt.ylabel('No. of accidents')
plt.xlabel('Time')
plt.title('Number of passenger accidents in day vs night(Time: 0 to 23)')
plt.xticks(x, labels)
plt.show()

# %% [markdown]
# Above data and graphs confirm that among all the groups the crossing users have maximum number of accidents, followed by employess and passengers.
# Also, more people get injured over killed in these accidents.

# %% [markdown]
# ## Accidents plotted against Gender and Age

# %%
(pd.pivot_table(df_rail_road_crossing_accident, values="Accidents", index=None, columns=["User Gender"], aggfunc="sum").T).dropna()
# Out:
#              Accidents
# User Gender
# Female          8581.0
# Male           23235.0

# %%
#in last 10 years
(pd.pivot_table(df_recent_accidents, values="Accidents", index=None, columns=["User Gender"], aggfunc="sum").T).dropna()
# Out:
#              Accidents
# User Gender
# Female          3211.0
# Male            8664.0

# %%
(pd.pivot_table(df_rail_road_crossing_accident, values="Accidents", index=None, columns=["User Age","User Gender"], aggfunc="sum").T).dropna()
# Out:
#                       Accidents
# User Age User Gender
# 1.0      Female             0.0
#          Male               0.0
# 2.0      Male               1.0
# 5.0      Male               3.0
# 6.0      Male               2.0
# ...                         ...
# 97.0     Male               1.0
# 98.0     Female             0.0
#          Male               4.0
# 99.0     Female             0.0
#          Male               5.0
#
# [187 rows x 1 columns]

# %%
genderwise_accidents_dataset = (df_rail_road_crossing_accident.groupby(["User Age","User Gender"])["Accidents"].sum()).to_frame(name = 'Total_Accidents').reset_index()
#print(genderwise_accidents_dataset)
genderwise_accidents_dataset.rename(columns={'User Gender':'Gender','User Age':'Age'},inplace=True)

sns.set_theme(style="darkgrid")
sns.lineplot(x="Age", y="Total_Accidents",hue="Gender",data=genderwise_accidents_dataset)

# %%
g = sns.PairGrid(genderwise_accidents_dataset, y_vars=["Total_Accidents"], x_vars=["Gender", "Age"], hue="Gender", height=4.5, aspect=1.1)
ax = g.map(plt.scatter, alpha=0.2)
g.add_legend();

# %% [markdown]
# ***It is clear from our analysis that more Male suffered rail road accidents over Female. The age group which was affected the most was between 20-40 years of age.***

# %% [markdown]
# ##Accidents with different vehicle speeds:

# %%
(pd.pivot_table(df_rail_road_crossing_accident, values="Accidents", index=None, columns="Estimated Vehicle Speed", aggfunc="sum").T).dropna()
# Out:
#                          Accidents
# Estimated Vehicle Speed
# 0.0                        16116.0
# 1.0                         1581.0
# 2.0                         2291.0
# 3.0                         2534.0
# 4.0                         1163.0
# ...                            ...
# 210.0                          0.0
# 215.0                          0.0
# 404.0                          1.0
# 409.0                          0.0
# 510.0                          0.0
#
# [95 rows x 1 columns]

# %%
df_veh_speed= (df_rail_road_crossing_accident.groupby(["Estimated Vehicle Speed"])["Accidents"].sum()).to_frame(name = 'Total_Accidents').reset_index()
#print(df_veh_speed)

# exporting to a csv file                                                             
df_veh_speed.to_csv(r'/content/df_veh_speed.csv', index=False)

# %%
low_vehicle_speed = df_veh_speed[(df_veh_speed['Estimated Vehicle Speed']>=0) & (df_veh_speed['Estimated Vehicle Speed']<=30)].shape[0] / df_veh_speed.shape[0]
print("low_speed:", low_vehicle_speed)
# Out:
# low_speed: 0.3263157894736842

# %%
fast_vehicle_speed = df_veh_speed[(df_veh_speed['Estimated Vehicle Speed']>30) & (df_veh_speed['Estimated Vehicle Speed']<=60)].shape[0] / df_veh_speed.shape[0]
print("fast_vehicle_speed:", fast_vehicle_speed)
# Out:
# fast_vehicle_speed: 0.3157894736842105

# %%
superfast_vehicle_speed = df_veh_speed[(df_veh_speed['Estimated Vehicle Speed']>60)].shape[0] / df_veh_speed.shape[0]
print("superfast_vehicle_speed:", superfast_vehicle_speed)

vehicle_speed = [low_vehicle_speed,fast_vehicle_speed,superfast_vehicle_speed]
# Out:
# superfast_vehicle_speed: 0.35789473684210527

# %%
y = vehicle_speed
mylabels = ["Slow", "Fast", "Super-fast"]
myexplode = [0.1, 0.1, 0.1]
mycolor = ['pink','lightgreen','lightskyblue']

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True, radius= 1.5, colors=mycolor)
plt.legend(title = "Vehicle speed:")
plt.show()

# %% [markdown]
# **It is clear that maximum accidents took place with super high speed vehicles followed by slow and fast speed vehicles.**

# %% [markdown]
# ##Accidents and speed of trains:

# %%
(pd.pivot_table(df_recent_accidents, values="Accidents", index=None, columns="Train Speed", aggfunc="sum").T).dropna()
# Out:
#              Accidents
# Train Speed
# 1.0               32.0
# 2.0               74.0
# 3.0               90.0
# 4.0              108.0
# 5.0              213.0
# ...                ...
# 88.0               0.0
# 90.0               2.0
# 95.0               2.0
# 108.0              1.0
# 110.0              6.0
#
# [91 rows x 1 columns]

# %%
df_train_speed= (df_rail_road_crossing_accident.groupby(["Train Speed"])["Accidents"].sum()).to_frame(name = 'Total_Accidents').reset_index()
#print(df_train_speed)

# %%
low_speed = df_train_speed[(df_train_speed['Train Speed']>=0) & (df_train_speed['Train Speed']<=30)].shape[0] / df_train_speed.shape[0]
print("low_speed:", low_speed)
# Out:
# low_speed: 0.29523809523809524

# %%
fast_speed = df_train_speed[(df_train_speed['Train Speed']>30) & (df_train_speed['Train Speed']<=60)].shape[0] / df_train_speed.shape[0]
print("fast_speed:", fast_speed)
# Out:
# fast_speed: 0.2857142857142857

# %%
superfast_speed = df_train_speed[(df_train_speed['Train Speed']>60)].shape[0] / df_train_speed.shape[0]
print("superfast_speed:", superfast_speed)

speed = [low_speed,fast_speed,superfast_speed]
# Out:
# superfast_speed: 0.41904761904761906

# %%
y = speed
mylabels = ["Slow", "Fast", "Super-fast"]
myexplode = [0, 0, 0.1]
mycolor = ['cornflowerblue','deepskyblue','lightskyblue']

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True, radius= 1.5, colors=mycolor )
plt.legend(title = "Train speed:")
plt.show()

# %% [markdown]
# **It is clear that maximum accidents took place with trains at high speed and the number of accidents with low speed and fast speed trains are almost the same.**

# %% [markdown]
# ##Accidents and different visibilities :

# %%
(pd.pivot_table(df_rail_road_crossing_accident, values="Accidents", index=None, columns=["Visibility"], aggfunc="sum").T).dropna()
# Out:
#             Accidents
# Visibility
# Dark          38179.0
# Dawn           3114.0
# Day           66984.0
# Dusk           4587.0

# %% [markdown]
# It is clear from our data analysis that most of the accidents took place in the day with good visibility, followed by dark and dusk.

# %% [markdown]
# ##Accidents affected by User Actions and lights at the crossing signals

# %%
#Crossing Illuminated:
(pd.pivot_table(df_rail_road_crossing_accident, values="Accidents", index=None, columns=["Crossing Illuminated"], aggfunc="sum").T).dropna()
# Out:
#                       Accidents
# Crossing Illuminated
# No                      64953.0
# Unknown                 20225.0
# Yes                     24229.0

# %% [markdown]
# It is clear from our analysis that with proper illumintaion the number of accidents reduces significantly.

# %%
#Highway User Action
(pd.pivot_table(df_rail_road_crossing_accident, values="Accidents", index=None, columns=["Highway User Action"], aggfunc="sum").T).dropna()
# Out:
#                                       Accidents
# Highway User Action
# Did not stop                            71166.0
# Other                                    4423.0
# Stopped and then proceeded               5347.0
# Stopped on crossing                     15748.0
# Suicide/attempted suicide                 471.0
# Went around the gate                    12236.0
# Went around/thru temporary barricade        4.0
# Went thru the gate                        636.0

# %% [markdown]
# The above data sugests that maximum rail road accidents happens when users don't stop at the railway crossing

# %%
(pd.pivot_table(df_rail_road_crossing_accident, values="Accidents", index=None, columns=["Highway User Action","Crossing Illuminated"], aggfunc="sum").T).dropna()
# Out:
#                                                            Accidents
# Highway User Action                  Crossing Illuminated
# Did not stop                         No                      43106.0
#                                      Unknown                 13124.0
#                                      Yes                     12490.0
# Other                                No                       2633.0
#                                      Unknown                   475.0
#                                      Yes                      1265.0
# Stopped and then proceeded           No                       3208.0
#                                      Unknown                   863.0
#                                      Yes                      1091.0
# Stopped on crossing                  No                       9669.0
#                                      Unknown                  2756.0
#                                      Yes                      2750.0
# ...

# %%
df_acc_variables= (df_rail_road_crossing_accident.groupby(["Highway User Action","Crossing Illuminated"])["Accidents"].sum()).to_frame(name = 'Total_Accidents').reset_index()

# exporting to a csv file                                                             
df_acc_variables.to_csv(r'/content/df_acc_variables.csv', index=False)


plt.figure(figsize=(20,8))
sns.lineplot(x="Highway User Action", y="Total_Accidents",hue="Crossing Illuminated",linewidth=2, data=df_acc_variables)
plt.xticks(rotation=30, ha='right')
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7], <a list of 8 Text major ticklabel objects>)

# %% [markdown]
# # Correlation between features:
# Correlation heatmap showing different features and their density to the rail road accidents

# %%
dfCorr = df_rail_road_crossing_accident.corr()
filteredDf = dfCorr[((dfCorr >= .05) | (dfCorr <= -.1)) & (dfCorr !=1.000)]
plt.figure(figsize=(30,10))
sns.heatmap(filteredDf, annot=True, cmap="Reds")
plt.show()

# %% [markdown]
# #Data Prediction in State with largest number of accidents(Texas):
# Our goal is to make a simple model that can predict whether an accident will take place or not based on the historical data from columns having predictive power.

# %% [markdown]
# Converting Categorical Data to Numerical Data:

# %%
# taking columns which have predictive power
accidents_prediction = (df_rail_road_crossing_accident.groupby([ 'Train Speed','Time','Month','Roadway Condition','Crossing Illuminated','State Name','Report Year','Estimated Vehicle Speed','Number People On Train','Employees Killed For Reporting Railroad', 
                                                                'Visibility','Employees Injured For Reporting Railroad','Passengers Killed For Reporting Railroad','Passengers Injured For Reporting Railroad','Crossing Users Killed For Reporting Railroad',
                                                                'Crossing Users Injured For Reporting Railroad','Highway User Position Code','Total Killed Form 57','Total Injured Form 57'])
                                                             ["Accidents"].sum()).to_frame(name = 'Total_Accidents').sort_values(['Total_Accidents'],ascending=False).reset_index() 
                                                             
accidents_prediction.replace(np.nan,0, inplace = True)
# adding condition to predict Accidents only for Texas
final_dataset = accidents_prediction[accidents_prediction['State Name'] == 'TEXAS']
df_dummified = pd.get_dummies(final_dataset, drop_first=True)   # One-hot encoding
df_dummified.head(3)
# Out:
#     Train Speed  Time  Month  Report Year  Estimated Vehicle Speed  \
# 6          62.0  16.0     11         2012                      4.0
# 11         60.0  15.0      8         2019                     25.0
# 45         38.0  13.0      1         2015                      5.0
#
#     Number People On Train  Employees Killed For Reporting Railroad  \
# 6                      2.0                                      0.0
# 11                    80.0                                      0.0
# 45                     2.0                                      0.0
#
#     Employees Injured For Reporting Railroad  \
# 6                                        0.0
# 11                                       0.0
# 45                                       0.0
#
#     Passengers Killed For Reporting Railroad  \
# 6                                        0.0
# 11                                       0.0
# 45                                       0.0
#
# ...

# %%
# exporting to a csv file                                                             
accidents_prediction.to_csv(r'/content/accidents_prediction1.csv', index=False)

# %% [markdown]
# Observation:

# %% [markdown]
# * November, 2012 saw the maximum number of railroad crossing accidents.
# * Majority of the accidents take place at train speeds of 60 mph and people crossing at speeds of 5-25 mph.
# * Accidents take place mainly during peak visibility during the day and between 3pm-5pm.
# * The road condition at the time of accidents was mostly dry,there was no ice or water logged.
# * The accidents were particularly fatal for crossing users and passengers in the trains in most of the cases.

# %%
X_df = df_dummified.drop('Total_Accidents', axis=1) 
y_df = df_dummified['Total_Accidents']

# %%
#checking shape
print("X_df:", X_df.shape)
print("y_df:", y_df.shape)
# Out:
# X_df: (2077, 25)
# y_df: (2077,)

# %% [markdown]
# Supervised learning with Gaussian Model:
# From X_df and y_df creating the train/test splits.
#
# * Setting 50% of the data to test and the rest data to train.
# * Naming the resulting objects: Xtrain, Xtest, ytrain, ytest.

# %%
from sklearn.model_selection import train_test_split
Xtrain, Xtest, ytrain, ytest = train_test_split(X_df, y_df, test_size=0.5, random_state=833)

# %%
print("Xtrain shape:", Xtrain.shape)
print("Xtest shape:", Xtest.shape)
# Out:
# Xtrain shape: (1038, 25)
# Xtest shape: (1039, 25)

# %%
from sklearn.naive_bayes import GaussianNB # 1. choose model class
model = GaussianNB()                       # 2. instantiate model
model.fit(Xtrain, ytrain)                  # 3. fit model to data
y_model = model.predict(Xtest)             # 4. predict on new data

# %%
print("Our model is", round(sum(ytest == y_model)/len(y_model),2), "accurate!")
# Out:
# Our model is 0.67 accurate!

# %%
from sklearn.metrics import accuracy_score
accuracy_score(ytest, y_model)
# Out:
# 0.670837343599615

# %% [markdown]
# ##Is our model good enough?
#
# If we had said there will be no accidents, what the accuracy would have been?
#
# Calculating the accuracy for our simplistic model below:
#
# Here 0 represents no accident, anything not equal to zero represents an accident.

# %% [markdown]
# Checking goodness of the model:

# %%
sum(ytest == 0)/len(ytest)
# Out:
# 0.6525505293551492

# %% [markdown]
# So, after all our ML model is not that great.

# %% [markdown]
# How much data did we have in the test dataset?

# %%
len(ytest)
#len(y_model)
# Out:
# 1039

# %% [markdown]
# How many of the accidents are not 0(how many accidnets took place) ?

# %%
P = sum(ytest != 0)
P
# Out:
# 361

# %% [markdown]
# How many true positives did the model generate?

# %%
TP = sum((ytest != 0) & (y_model != 0))
TP
# Out:
# 361

# %% [markdown]
# True positive sensitivity:

# %%
TP/P
# Out:
# 1.0

# %%
N = sum(ytest == 0)
N
# Out:
# 678

# %%
TN = sum((ytest == 0) & (y_model == 0))
TN
# Out:
# 670

# %% [markdown]
# True negative rate (or specificity):

# %%
TN/N
# Out:
# 0.9882005899705014

# %% [markdown]
# # Dashboard:
# Below is the tableau dashboard image and url for our data analysis: https://public.tableau.com/app/profile/richa1044/viz/PythonAssignment/RailroadCrossingAccidentsDashboard?publish=yes
#
#
#  <img style="width:100%" align="center" src="https://raw.githubusercontent.com/richaquestrom/Business-Analytics/main/Screen Shot 2022-05-01 at 8.16.32 PM.png" width="600" align="center">
#
#
# Below are the images of the python notebook deployed on the Google Cloud:
# <img style="width:100%" align="center" src="https://raw.githubusercontent.com/richaquestrom/Business-Analytics/main/Screen Shot 2022-04-29 at 9.07.23 PM.png" width="600" align="center">
#
# <img style="width:100%" align="center" src="https://raw.githubusercontent.com/richaquestrom/Business-Analytics/main/Screen Shot 2022-04-29 at 9.07.40 PM.png" width="600" align="center">

# %% [markdown]
# # Overall data observations (Report Summary):
# In order to understand the reasons behind railroad accidents in the United States, we started with visualizing definite patterns between various factors contributing to railway road accidents(i.e. correlation between feature columns and target column)with data and graphs. As a part of process of data analysis we cleaned our data first and defined our target and feature columns and remove any unnecessary data from the dataset to predict better.
# Our overall observations for railroad accidents are below:
# 1. We have seen reduction in rail road accidents from 1975 to 2021
# 2. Texas remained the state with maximum number of rail road accidents in all these years
# 3. The number of accidents in day exceeds night, as people travel more during day vs night
# 4. Male with age 20-40 have suffered the most with rail road accidents
# 5. Most of the accidents took place under clear weather conditions
# 6. Most of the accidents took place when either the train or the vehicle had very fast speed
# 7. And finally most of the accidents took place as a result of crossing user ignorance
#
# Further we tried to find factors responsible for maximum number of accidents in Texas(state with largest number of accidents consistently). We defined a simple Gaussian Naive Bayes model with categorical columns having good prediction power. We further made test and train datasets to check accuracy of our model. As a result we got to know that our model is 67% accurate. We also checked the goodness of our model with sensitivity and specificity. And at last, we deployed our Data Analysis notebook on the Google Cloud. We could use a more sophisticated algorithm, such as convolutional neural networks (CNN), random forests, or another classification approach, to go beyond our current classification rate of 67%. Our model's efficiency could be improved by incorporating additional features related to railroad accidents.
